# %% [markdown]
# # Module 12 Challenge
# ## Deliverable 1: Scrape Titles and Preview Text from Mars News

# %%
# Import Splinter and BeautifulSoup
from splinter import Browser
from bs4 import BeautifulSoup as soup
from webdriver_manager.chrome import ChromeDriverManager

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)

# %% [markdown]
# ### Step 1: Visit the Website
#
# 1. Use automated browsing to visit the [Mars NASA news site](https://redplanetscience.com). Inspect the page to identify which elements to scrape.
#
#       > **Hint** To identify which elements to scrape, you might want to inspect the page by using Chrome DevTools.

# %%
# Visit the Mars NASA news site: https://redplanetscience.com
url = 'https://redplanetscience.com'
browser.visit(url)

# %% [markdown]
# ### Step 2: Scrape the Website
#
# Create a Beautiful Soup object and use it to extract text elements from the website.

# %%
# Create a Beautiful Soup object
html = browser.html
news_soup = soup(html, 'html.parser')

# %%
# Extract all the text elements
titles = news_soup.find_all('div', class_='content_title')
previews = news_soup.find_all('div', class_='article_teaser_body')

# %% [markdown]
# ### Step 3: Store the Results
#
# Extract the titles and preview text of the news articles that you scraped. Store the scraping results in Python data structures as follows:
#
# * Store each title-and-preview pair in a Python dictionary. And, give each dictionary two keys: `title` and `preview`. An example is the following:
#
#   ```python
#   {'title': "Mars Rover Begins Mission!",
#         'preview': "NASA's Mars Rover begins a multiyear mission to collect data about the little-explored planet."}
#   ```
#
# * Store all the dictionaries in a Python list.
#
# * Print the list in your notebook.

# %%
# Create an empty list to store the dictionaries
mars_news = []

# %%
# Loop through the text elements
# Extract the title and preview text from the elements
# Store each title and preview pair in a dictionary
# Add the dictionary to the list
for x in titles:
    for p in previews:
        mars_news.append(dict(title=x.text, preview=p.text))

# %%
#mars_titles = [dict(zip(["title"],[x.text])) for x in titles]
#mars_previews = [dict(zip(["preview"],[p.text])) for p in previews]
#mars_news = mars_titles + mars_previews

# %%
# Print the list to confirm success
mars_news
# Out:
# [{'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "Meet the People Behind NASA's Perseverance Rover",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "Curiosity Mars Rover's Summer Road Trip Has Begun",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "NASA's Mars 2020 Rover Completes Its First Drive",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': 'NASA Invites Students to Name Mars 2020 Rover',
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "NASA's Perseverance Rover 100 Days Out",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': 'Mars Scientists Investigate Ancient Life in Australia',
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "3 Things We've Learned From NASA's Mars InSight ",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network',
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'},
#  {'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above",
#   'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}]

# %%
browser.quit()

# %% [markdown]
# ### (Optional) Step 4: Export the Data
#
# Optionally, store the scraped data in a file or database (to ease sharing the data with others). To do so, export the scraped data to either a JSON file or a MongoDB database.

# %%
# Export data to JSON

# %%
# Export data to MongoDB
from pymongo import MongoClient
mongo = MongoClient(port=27017)
News_db = mongo['mars_db']
News_coll = News_db['mars_coll']
News_coll.insert_many(mars_news)

# %%
#MongoDB
print(mongo.list_database_names())
# Out:
# ['admin', 'config', 'local', 'mars_db']

# %%
#MongoDB
print(News_db.list_collection_names())
# Out:
# ['mars_coll']

# %%
#MongoDB
results = News_coll.find()
for result in results:
    print(result)
# Out:
# {'_id': ObjectId('639a6c207107d0c90f4ef346'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef347'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef348'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef349'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef34a'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef34b'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef34c'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef34d'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef34e'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef34f'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef350'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef351'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef352'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef353'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef354'), 'title': "Meet the People Behind NASA's Perseverance Rover", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef355'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef356'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef357'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef358'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef359'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef35a'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef35b'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef35c'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef35d'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef35e'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef35f'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef360'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef361'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef362'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef363'), 'title': "NASA's Curiosity Mars Rover Takes a New Selfie Before Record Climb", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef364'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef365'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef366'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef367'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef368'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef369'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef36a'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef36b'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef36c'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef36d'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef36e'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef36f'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef370'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef371'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef372'), 'title': "Curiosity Mars Rover's Summer Road Trip Has Begun", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef373'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef374'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef375'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef376'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef377'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef378'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef379'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef37a'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef37b'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef37c'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef37d'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef37e'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef37f'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef380'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef381'), 'title': "Virginia Middle School Student Earns Honor of Naming NASA's Next Mars Rover", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef382'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef383'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef384'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef385'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef386'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef387'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef388'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef389'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef38a'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef38b'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef38c'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef38d'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef38e'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef38f'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef390'), 'title': "NASA's Mars 2020 Rover Completes Its First Drive", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef391'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef392'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef393'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef394'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef395'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef396'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef397'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef398'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef399'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef39a'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef39b'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef39c'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef39d'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef39e'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef39f'), 'title': "The Launch Is Approaching for NASA's Next Mars Rover, Perseverance", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a0'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a1'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a2'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a3'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a4'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a5'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a6'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a7'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a8'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3a9'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3aa'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ab'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ac'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ad'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ae'), 'title': 'NASA Invites Students to Name Mars 2020 Rover', 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3af'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b0'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b1'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b2'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b3'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b4'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b5'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b6'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b7'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b8'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3b9'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ba'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3bb'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3bc'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3bd'), 'title': "NASA Readies Perseverance Mars Rover's Earthly Twin ", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3be'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3bf'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c0'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c1'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c2'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c3'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c4'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c5'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c6'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c7'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c8'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3c9'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ca'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3cb'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3cc'), 'title': "Newfound Martian Aurora Actually the Most Common; Sheds Light on Mars' Changing Climate", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3cd'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ce'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3cf'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d0'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d1'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d2'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d3'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d4'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d5'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d6'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d7'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d8'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3d9'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3da'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3db'), 'title': "NASA's Perseverance Rover 100 Days Out", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3dc'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3dd'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3de'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3df'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e0'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e1'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e2'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e3'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e4'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e5'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e6'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e7'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e8'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3e9'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ea'), 'title': 'Mars Scientists Investigate Ancient Life in Australia', 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3eb'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ec'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ed'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ee'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ef'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f0'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f1'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f2'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f3'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f4'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f5'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f6'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f7'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f8'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3f9'), 'title': "3 Things We've Learned From NASA's Mars InSight ", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3fa'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef3fb'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3fc'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3fd'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef3fe'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef3ff'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef400'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef401'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef402'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef403'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef404'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef405'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef406'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef407'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef408'), 'title': "NASA's InSight 'Hears' Peculiar Sounds on Mars", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef409'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef40a'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef40b'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef40c'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef40d'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef40e'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef40f'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef410'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef411'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef412'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef413'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef414'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef415'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef416'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef417'), 'title': 'NASA Prepares for Moon and Mars With New Addition to Its Deep Space Network', 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef418'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "These are the scientists and engineers who built NASA's next Mars rover and who will guide it to a safe landing in Jezero Crater. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef419'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'Along with capturing an image before its steepest ascent ever, the robotic explorer filmed its "selfie stick," or robotic arm, in action.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef41a'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'After more than a year in the "clay-bearing unit," Curiosity is making a mile-long journey around some deep sand so that it can explore higher up Mount Sharp.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef41b'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'NASA chose a seventh-grader from Virginia as winner of the agency\'s "Name the Rover" essay contest. Alexander Mather\'s entry for "Perseverance" was voted tops among 28,000 entries. '}
# {'_id': ObjectId('639a6c207107d0c90f4ef41c'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'In a 10-plus-hour marathon, the rover steered, turned and drove in 3-foot (1-meter) increments over small ramps.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef41d'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "The Red Planet's surface has been visited by eight NASA spacecraft. The ninth will be the first that includes a roundtrip ticket in its flight plan. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef41e'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "Through Nov. 1, K-12 students in the U.S. are encouraged to enter an essay contest to name NASA's next Mars rover."}
# {'_id': ObjectId('639a6c207107d0c90f4ef41f'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "Did you know NASA's next Mars rover has a nearly identical sibling on Earth for testing? Even better, it's about to roll for the first time through a replica Martian landscape."}
# {'_id': ObjectId('639a6c207107d0c90f4ef420'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'A type of Martian aurora first identified by NASA’s MAVEN spacecraft in 2016 is actually the most common form of aurora occurring on the Red Planet, according to new results from the mission.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef421'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "Mark your calendars: The agency's latest rover has only about 8,640,000 seconds to go before it touches down on the Red Planet, becoming history's next Mars car."}
# {'_id': ObjectId('639a6c207107d0c90f4ef422'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': "Teams with NASA's Mars 2020 and ESA's ExoMars practiced hunting for fossilized microbial life in the Australian Outback in preparation for their Red Planet missions. "}
# {'_id': ObjectId('639a6c207107d0c90f4ef423'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'Scientists are finding new mysteries since the geophysics mission landed two years ago.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef424'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'Listen to the marsquakes and other, less-expected sounds that the Mars lander has been detecting.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef425'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'Robotic spacecraft will be able to communicate with the dish using radio waves and lasers.'}
# {'_id': ObjectId('639a6c207107d0c90f4ef426'), 'title': "Celebrate Mars Reconnaissance Orbiter's Views From Above", 'preview': 'Marking its 15th anniversary since launch, one of the oldest spacecraft at the Red Planet has provided glimpses of dust devils, avalanches, and more.'}
